# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.8/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.8/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.8/site-packages (from pandas) (2025.3)
# Requirement already satisfied: numpy>=1.20.3 in ./.venv/lib/python3.8/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
spotifyData = pd.read_csv('spotify_data_clean.csv')
spotifyData.head(10)
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
# 5  4ccpCcZYseq8VrPMK1EDs0                                            BLEED
# 6  3QoQ3HqXTAjgEl9LbNMbYp                             Te Procuro na Cidade
# 7  1YEZbdT417SfolPQzaoHs2                                      come closer
# 8  4pZ949nFW5SurwzE0TSe7I                                 Cupido Vagabundo
# 9  0L0LgwFZ7UtBnRNQvSBty6                                        LET’S GO!
#
#    track_number  track_popularity  explicit     artist_name  \
# 0             4                 0      True           Diplo
# 1             1                 0      True        Yelawolf
# 2             1                 4      True       Riff Raff
# 3             8                30      True           Diplo
# 4             2                 0      True         Rumelis
# 5             1                 2     False          Minzie
# 6             1                20     False          AZERDK
# 7             1                27     False         Rumelis
# 8             1                16     False  Toni dos Anjos
# 9             1                33      True        PsychoYP
#
#    artist_popularity  artist_followers  \
# 0                 77           2812821
# 1                 64           2363438
# 2                 48            193302
# 3                 77           2813710
# 4                 48              8682
# 5                 46              7218
# 6                 30              1657
# 7                 49              8802
# 8                  6               475
# 9                 48            154802
#
#                                        artist_genres                album_id  \
# 0                                         moombahton  5QRFnGnBeMGePBKF2xTz5z
# 1                  country hip hop, southern hip hop  4SUmmwnv0xTjRcLdjczGg2
# 2                                                NaN  3E3zEAL8gUYWaLYB9L7gbp
# 3                                         moombahton  5QRFnGnBeMGePBKF2xTz5z
# 4                                           dark r&b  06FDIpSHYmZAZoyuYtc7kd
# 5                                           dark r&b  2NQv9p3ZQW0Ed1LB9enix8
# 6                                                NaN  1PpuOsLjPWshDLxkr0oHeU
# 7                                           dark r&b  06FDIpSHYmZAZoyuYtc7kd
# 8                                                NaN  60DLQZkzpvDvVfvEC6VOJM
# 9  nigerian drill, alté, afro adura, afrobeats, a...  3ARxksm8CspGeAaZZB1v2w
#
#                             album_name album_release_date  album_total_tracks  \
# 0                   d00mscrvll, Vol. 1         2025-10-31                   9
# 1                                 OMG!         2025-10-31                   1
# 2                          Hard 2 Find         2025-10-31                   1
# 3                   d00mscrvll, Vol. 1         2025-10-31                   9
# 4  come closer / ride me like a harley         2025-10-30                   2
# 5                                BLEED         2025-10-30                   3
# 6                 Te Procuro na Cidade         2025-10-30                   1
# 7  come closer / ride me like a harley         2025-10-30                   2
# 8                     Cupido Vagabundo         2025-10-30                   2
# 9                            LET’S GO!         2025-10-28                   1
#
#   album_type  track_duration_min
# 0      album                1.55
# 1     single                3.07
# 2     single                2.55
# 3      album                1.69
# 4     single                2.39
# 5     single                2.76
# 6     single                4.12
# 7     single                2.53
# 8     single                2.92
# 9     single                2.40

# %%
# 1 Cuales son los 10 artistas con mayor popularidad promedio en sus canciones?
# los parentesis se usan por comodidad de escritura, para poder hacer un salto de linea
top_artists = (
    spotifyData.groupby('artist_name')['track_popularity']
    .mean()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)
top_artists.columns = ['Artista', 'Popularidad Promedio']
top_artists['Popularidad Promedio'] = top_artists['Popularidad Promedio'].round(2)
print(top_artists)
# Out:
#        Artista  Popularidad Promedio
# 0      HUNTR/X                 93.75
# 1    Saja Boys                 93.50
# 2  Disco Lines                 92.00
# 3         Rumi                 91.00
# 4  Olivia Dean                 90.33
# 5   The Police                 90.00
# 6      W Sound                 89.00
# 7          Djo                 89.00
# 8      KATSEYE                 88.67
# 9        JISOO                 88.00

# %%
# 2 Las canciones explicitas son mas populares que las no explicitas?
explicit_comparison = (
    spotifyData.groupby('explicit')['track_popularity']
    .agg(['mean', 'count'])
    .reset_index()
)
explicit_comparison.columns = ['Explícita', 'Popularidad Promedio', 'Cantidad de canciones']
explicit_comparison['Popularidad Promedio'] = explicit_comparison['Popularidad Promedio'].round(2)
print(explicit_comparison)
# Out:
#    Explícita  Popularidad Promedio  Cantidad de canciones
# 0      False                 50.53                   6434
# 1       True                 57.82                   2148

# %%
# 3 ¿Cuáles son los 10 artistas con mayor número de seguidores en Spotify?

top_followed_artists = (
    spotifyData.groupby('artist_name')['artist_followers']
    .max()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

top_followed_artists.columns = ['Artista', 'Seguidores']
print(top_followed_artists)
# Out:
#          Artista  Seguidores
# 0   Taylor Swift   145542136
# 1     Ed Sheeran   122802777
# 2  Billie Eilish   118797451
# 3     The Weeknd   113039308
# 4  Ariana Grande   107418606
# 5         Eminem   104584370
# 6          Drake   103126025
# 7      Bad Bunny   102610644
# 8  Justin Bieber    85050158
# 9            BTS    81197976

# %%
#4 ¿Qué tipo de álbum tiene canciones más populares?
album_popularity = (
    spotifyData.groupby('album_type')['track_popularity']
    .agg(['mean','count'])
    .sort_values(by='mean', ascending=False)
    .reset_index()
)

album_popularity.columns = ['Tipo de Álbum', 'Popularidad Promedio', 'Cantidad de Canciones']
album_popularity['Popularidad Promedio'] = album_popularity['Popularidad Promedio'].round(2)

print(album_popularity)
# Out:
#   Tipo de Álbum  Popularidad Promedio  Cantidad de Canciones
# 0         album                 55.66                   5856
# 1        single                 46.36                   2219
# 2   compilation                 40.51                    507

# %%
#5 ¿Qué género tiene canciones más populares en promedio?

genre_popularity = (
    spotifyData.groupby('artist_genres')['track_popularity']
    .agg(['mean', 'count'])
    .sort_values(by='mean', ascending=False)
    .reset_index()
)

genre_popularity.columns = ['Género', 'Popularidad Promedio', 'Cantidad de Canciones']
genre_popularity['Popularidad Promedio'] = genre_popularity['Popularidad Promedio'].round(2)

print(genre_popularity.head(15))
# Out:
#                                                Género  Popularidad Promedio  \
# 0                                            pop soul                 90.33
# 1   corrido, corridos tumbados, corridos bélicos, ...                 87.00
# 2                         alternative r&b, indie soul                 86.50
# 3                               yacht rock, soft rock                 86.00
# 4                          west coast hip hop, g-funk                 86.00
# 5                                  soft pop, neo soul                 85.00
# 6          brazilian funk, trap funk, funk consciente                 85.00
# 7        rock, hard rock, classic rock, rock and roll                 84.67
# 8                                   reggaeton chileno                 84.00
# 9                            reggaeton, urbano latino                 84.00
# 10  glam rock, glam metal, hard rock, rock, classi...                 84.00
# 11                 latin house, afro house, techengue                 84.00
# 12                            country, outlaw country                 84.00
# 13  corrido, corridos tumbados, corridos bélicos, ...                 83.00
# 14  folk rock, folk, singer-songwriter, roots rock...                 82.00
#
#     Cantidad de Canciones
# 0                       3
# 1                       2
# 2                       2
# 3                       1
# 4                       1
# 5                       1
# 6                       1
# 7                       3
# 8                       1
# 9                       1
# 10                      1
# 11                      1
# 12                      1
# 13                      1
# 14                      1
